# %%
pip install wordcloud plottable matplotlib-venn
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Collecting plottable
#   Downloading plottable-0.1.5-py3-none-any.whl.metadata (3.2 kB)
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      -------------------------------------- 40.3/40.3 kB 969.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: pandas in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from plottable) (2.2.2)
# Requirement already satisfied: scipy in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from pandas->plottable) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from pandas->plottable) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    -------------------- ------------------- 153.6/300.6 kB 4.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 266.2/300.6 kB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 300.6/300.6 kB 2.7 MB/s eta 0:00:00
# Downloading plottable-0.1.5-py3-none-any.whl (24 kB)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45335 sha256=24229c314891f6a43b26be9b9075ee6c1fd29eddecc676717afef04792af30f6
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\5c\4b\48\d68a6531b1e1e7411520ab9f395994eb1ee2ffafd6837b7f6c
# Successfully built matplotlib-venn
# Installing collected packages: wordcloud, plottable, matplotlib-venn
# Successfully installed matplotlib-venn-1.1.1 plottable-0.1.5 wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(data=tips, # choose our dataset
             x='total_bill', # define our x variable
             y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style('whitegrid')

tipgraph = sns.lineplot(data=tips,
                        x='total_bill',
                        y='tip')
tipgraph.set(title='Tips vs. Total Bill',
             xlabel='Total Bill ($)',
             ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
fig = plt.subplots(figsize = (10,3))
tipgraph = sns.lineplot(data = tips,
                        x ='total_bill',
                        y ='tip',
                        color ='hotpink',
                        linestyle ='--',
                        linewidth =3,
                        marker ='o',
                        markerfacecolor ='indigo'
                        
                        )
tipgraph.set(
    title ='Tips vs Total Bill',
    xlabel ='Total Bill ($)',
    ylabel ='Tip Amount ($)'
)
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
tipgraph = sns.scatterplot(data = tips,
                        x ='total_bill',
                        y ='tip',
                        style ='time',
                        hue ='day',
                        palette= ['purple',
                                  'hotpink',
                                  'deepskyblue',
                                  'yellowgreen'
                                  ]
                        
                        )
tipgraph.set(
    title ='Tips vs Total Bill',
    xlabel ='Total Bill ($)',
    ylabel ='Tip Amount ($)'
)
# Out:
# [Text(0.5, 1.0, 'Tips vs Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
sns.pairplot(data = tips,
             hue = 'day')

# %%
sns.relplot(data= tips,
            x ='total_bill',
            y ='tip',
            hue ='sex', 
            col= 'day',
            kind = 'scatter',
            col_wrap=2)

# %%
import plotly.graph_objects as go
x1= np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y1= np.array([110,180,240,99,220])

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1,y=y1))

# %%
graph.update_layout(title ='Pirate Socres',
                    xaxis_title ='Prirates',
                    yaxis_title = 'Score')

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(
    x = x1,
    y =y1,
    mode ='markers',
    marker = dict(
        size =15,
        color = 'hotpink',
        opacity =1,
        line = dict(width =5, color ='purple')
    )
))
graph.update_layout(
    title = 'Interactive Prirate Plot',
    yaxis_title = 'Scores',
    xaxis_title ='Pirates',
    width = 500,
    height =500
)

# %%
pip install wordcloud plottable matplotlib-venn

# %%
from wordcloud import WordCloud

# %%
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
                 on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
text = " ".join(each for each in df.quote)
wordcloud = WordCloud(background_color= 'white', colormap='inferno').generate(text)

fig, ax = plt.subplots(figsize = (7,3))
ax.imshow(wordcloud,
          interpolation='bilinear')

ax.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# Making venn plot

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
A =set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])
diagram = venn2([A,B],
                set_labels =('Fruits','Pies'),
                set_colors =('blue','red'),
                alpha =0.5               

)

# %%
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
A =set(["apple","banana","watermelon"])
B = set(["pumpkin","blueberry","apple","key lime"])
diagram = venn2([A,B],
                set_labels =('Fruits','Pies'),
                set_colors =('blue','red'),
                alpha =0.5               

)
diagram.get_label_by_id("10").set_text("\n".join(A-B))
diagram.get_label_by_id("11").set_text("\n".join(A & B))
diagram.get_label_by_id("01").set_text("\n".join(B-A))
